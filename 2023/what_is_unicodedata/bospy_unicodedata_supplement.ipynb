# %% [markdown]
# ## Supplementary notebook for Boston Python's Study Group meeting on `unicodedata`
#
# This notebook contains a set of cells relating to discussion following
# a 25 May 2023 meeting of the [Boston Python](https://about.bostonpython.com)
# Study Group, which focused on the [`unicodedata` module](https://docs.python.org/3/library/unicodedata.html)
#
# I've reorganized and annotated the cells to hopefully make their
# context a bit more clear.

# %%
import unicodedata

# %% [markdown]
# ## What's the difference between a codepoint and encoded bytes?
#
# We discussed how a Unicode codepoint is the assignment of
# a "character" to an integer, but since that integer may be
# represented by multiple sequences of bytes, there are
# multiple encodings of any Unicode codepoint or sequence of codepoints

# %%
print(ord("a"))
print("a".encode("utf-8"))
print("a".encode("utf-16"))
print("a".encode("utf-32"))

print('---')

print(ord("二"))
print("二".encode("utf-8"))
print("二".encode("utf-16"))
print("二".encode("utf-32"))
# Out:
# 97
# b'a'
# b'\xff\xfea\x00'
# b'\xff\xfe\x00\x00a\x00\x00\x00'
# ---
# 20108
# b'\xe4\xba\x8c'
# b'\xff\xfe\x8cN'
# b'\xff\xfe\x00\x00\x8cN\x00\x00'

# %% [markdown]
# ## Looking up codepoints by name
#
# We talked about how to look up codepoints by name, as well as the fact that Python's support for `\N{NAME OF CODEPOINT}` relies on the same structure of Unicode

# %%
print(unicodedata.lookup("SNAKE"))
print("I love Python, it has such good Unicode support! \N{SNAKE}")
print(hex(ord("\N{SNAKE}")))
# Out:
# 🐍
# I love Python, it has such good Unicode support! 🐍
# 0x1f40d

# %% [markdown]
# ## Is there a limit to combining characters?
#
# We discussed the question of whether there is a limit to the behavior of combining characters, with [Zalgo text](https://en.wikipedia.org/wiki/Zalgo_text) as an extreme example of use of them

# %%
len("h̶͉̹̻̿̓e̷̥͘l̸̫̯̎l̷̢̗̔̓ò̵̆͜ ̴̥̬͂̔͋ẃ̷͕͛͑ô̸̝̻̋̽ŗ̴̘̇͌̉l̶̛̬̣̅̃d̶̢̹͙͆̏͗")  # that's a lot!
# Out:
# 69

# %% [markdown]
# ## Combining characters and bidirectional text in Hebrew
#
# We explored how to interrogate the combining characters present in Hebrew text, and also talked a bit about the directionality of text.
#
# We consulted a [list of Unicode combining categories](https://www.compart.com/en/unicode/combining) while looking at the output below

# %%
s = "hello world שָׁלוֹם"
for codept in s:
    print(
        unicodedata.name(codept),
        unicodedata.combining(codept),
        unicodedata.bidirectional(codept),
        sep="\t",
    )
# Out:
# LATIN SMALL LETTER H	0	L
# LATIN SMALL LETTER E	0	L
# LATIN SMALL LETTER L	0	L
# LATIN SMALL LETTER L	0	L
# LATIN SMALL LETTER O	0	L
# SPACE	0	WS
# LATIN SMALL LETTER W	0	L
# LATIN SMALL LETTER O	0	L
# LATIN SMALL LETTER R	0	L
# LATIN SMALL LETTER L	0	L
# LATIN SMALL LETTER D	0	L
# SPACE	0	WS
# HEBREW LETTER SHIN	0	R
# HEBREW POINT QAMATS	18	NSM
# HEBREW POINT SHIN DOT	24	NSM
# HEBREW LETTER LAMED	0	R
# HEBREW LETTER VAV	0	R
# HEBREW POINT HOLAM	19	NSM
# HEBREW LETTER FINAL MEM	0	R

# %%
# a human being considers these equivalent…
s1 = 'ça va?'
s2 = 'ça va?'

# …but they're not!
print(s1 == s2)

# we can get a hint about why by printing the lengths
print(len(s1), len(s2))
# Out:
# False
# 7 6

# %%
# Let's look at the name of each codepoint to find out what's going on here
for codept in s1:
    print(unicodedata.name(codept))

print('---')

for codept in s2:
    print(unicodedata.name(codept))
# Out:
# LATIN SMALL LETTER C
# COMBINING CEDILLA
# LATIN SMALL LETTER A
# SPACE
# LATIN SMALL LETTER V
# LATIN SMALL LETTER A
# QUESTION MARK
# ---
# LATIN SMALL LETTER C WITH CEDILLA
# LATIN SMALL LETTER A
# SPACE
# LATIN SMALL LETTER V
# LATIN SMALL LETTER A
# QUESTION MARK

# %% [markdown]
# ## Let's use [normalization forms](https://unicode.org/reports/tr15/) to transform these strings before we compare them
#
# Here we use Normalization Form C (NFC) to transform both strings
# into a "canonical composition" form, which in this case means that
# the cedilla is not a separate codepoint in both sequences.
#
# There are also Normalization Form D (NFD) that transforms strings
# to "canonical decomposition" form, and NFKC and NFKD forms that target
# "compatible composition" and decomposition forms, respectively.
# (the K is for "compatible" and avoids confusion with "canonical")

# %%
s1_norm = unicodedata.normalize("NFC", s1)
s2_norm = unicodedata.normalize("NFC", s2)

for codept in s1_norm:
    print(unicodedata.name(codept))
    
print('---')

for codept in s2_norm:
    print(unicodedata.name(codept))
    
print('---')
print(s1_norm == s2_norm)
# Out:
# LATIN SMALL LETTER C WITH CEDILLA
# LATIN SMALL LETTER A
# SPACE
# LATIN SMALL LETTER V
# LATIN SMALL LETTER A
# QUESTION MARK
# ---
# LATIN SMALL LETTER C WITH CEDILLA
# LATIN SMALL LETTER A
# SPACE
# LATIN SMALL LETTER V
# LATIN SMALL LETTER A
# QUESTION MARK
# ---
# True

# %% [markdown]
# ## Another normalization example
#
# Here we briefly discussed the importance of order of the combining characters in the NFD form

# %%
s = "\u1e69"
s_norm_d = unicodedata.normalize("NFD", s)
s_norm_c = unicodedata.normalize("NFC", s_norm_d)

print(s, len(s))

for codept in s_norm_d:
    print(unicodedata.name(codept))
    
for codept in s_norm_c:
    print(unicodedata.name(codept))
# Out:
# ṩ 1
# LATIN SMALL LETTER S
# COMBINING DOT BELOW
# COMBINING DOT ABOVE
# LATIN SMALL LETTER S WITH DOT BELOW AND DOT ABOVE

# %% [markdown]
# ## Example task: retrieve every 'numeric' codepoint and print the associated numeric properties
#
# In [Unicode's categories](https://www.compart.com/en/unicode/category),
# there are three numeric categories:
#
# * `Nl` for "letter number"
# * `Nd` for "digit number"
# * `No` for "other number"
#
# We can find all the numeric codepoints by checking every codepoint's
# category for a leading `'N'`
#
# Fun fact: the `sys` module provides a constant for the number
# of codepoints in Unicode. It's a historical artifact from a
# time when Python's Unicode support could vary between builds,
# see [PEP 393](https://peps.python.org/pep-0393/) for details.
#
# In this case, it's just a convenient way to loop over every codepoint.

# %%
import sys


for n in range(sys.maxunicode):
    char = chr(n)
    category = unicodedata.category(char)
    if category.startswith('N'):
        # note: we left-pad the name to align the output
        name = unicodedata.name(char).ljust(64)
        
        # note: these are three distinct concepts of
        # representing numbers with text, not all
        # numeric codepoints define then, so we include
        # a default value of None here
        decimal = unicodedata.decimal(char, None)
        digit = unicodedata.digit(char, None)
        numeric = unicodedata.numeric(char, None)
        
        print(char, name, category, decimal, digit, numeric, sep="\t")
# Out:
# 0	DIGIT ZERO                                                      	Nd	0	0	0.0
# 1	DIGIT ONE                                                       	Nd	1	1	1.0
# 2	DIGIT TWO                                                       	Nd	2	2	2.0
# 3	DIGIT THREE                                                     	Nd	3	3	3.0
# 4	DIGIT FOUR                                                      	Nd	4	4	4.0
# 5	DIGIT FIVE                                                      	Nd	5	5	5.0
# 6	DIGIT SIX                                                       	Nd	6	6	6.0
# 7	DIGIT SEVEN                                                     	Nd	7	7	7.0
# 8	DIGIT EIGHT                                                     	Nd	8	8	8.0
# 9	DIGIT NINE                                                      	Nd	9	9	9.0
# ²	SUPERSCRIPT TWO                                                 	No	None	2	2.0
# ³	SUPERSCRIPT THREE                                               	No	None	3	3.0
# ¹	SUPERSCRIPT ONE                                                 	No	None	1	1.0
# ¼	VULGAR FRACTION ONE QUARTER                                     	No	None	None	0.25
# ½	VULGAR FRACTION ONE HALF                                        	No	None	None	0.5
# ¾	VULGAR FRACTION THREE QUARTERS                                  	No	None	None	0.75
# ٠	ARABIC-INDIC DIGIT ZERO                                         	Nd	0	0	0.0
# ١	ARABIC-INDIC DIGIT ONE                                          	Nd	1	1	1.0
# ٢	ARABIC-INDIC DIGIT TWO                                          	Nd	2	2	2.0
# ٣	ARABIC-INDIC DIGIT THREE                                        	Nd	3	3	3.0
# ٤	ARABIC-INDIC DIGIT FOUR                                         	Nd	4	4	4.0
# ٥	ARABIC-INDIC DIGIT FIVE                                         	Nd	5	5	5.0
# ٦	ARABIC-INDIC DIGIT SIX                                          	Nd	6	6	6.0
# ٧	ARABIC-INDIC DIGIT SEVEN                                        	Nd	7	7	7.0
# ٨	ARABIC-INDIC DIGIT EIGHT                                        	Nd	8	8	8.0
# ٩	ARABIC-INDIC DIGIT NINE                                         	Nd	9	9	9.0
# ۰	EXTENDED ARABIC-INDIC DIGIT ZERO                                	Nd	0	0	0.0
# ۱	EXTENDED ARABIC-INDIC DIGIT ONE                                 	Nd	1	1	1.0
# ۲	EXTENDED ARABIC-INDIC DIGIT TWO                                 	Nd	2	2	2.0
# ۳	EXTENDED ARABIC-INDIC DIGIT THREE                               	Nd	3	3	3.0
# ۴	EXTENDED ARABIC-INDIC DIGIT FOUR                                	Nd	4	4	4.0
# ۵	EXTENDED ARABIC-INDIC DIGIT FIVE                                	Nd	5	5	5.0
# ۶	EXTENDED ARABIC-INDIC DIGIT SIX                                 	Nd	6	6	6.0
# ۷	EXTENDED ARABIC-INDIC DIGIT SEVEN                               	Nd	7	7	7.0
# ۸	EXTENDED ARABIC-INDIC DIGIT EIGHT                               	Nd	8	8	8.0
# ۹	EXTENDED ARABIC-INDIC DIGIT NINE                                	Nd	9	9	9.0
# ߀	NKO DIGIT ZERO                                                  	Nd	0	0	0.0
# ߁	NKO DIGIT ONE                                                   	Nd	1	1	1.0
# ߂	NKO DIGIT TWO                                                   	Nd	2	2	2.0
# ߃	NKO DIGIT THREE                                                 	Nd	3	3	3.0
# ߄	NKO DIGIT FOUR                                                  	Nd	4	4	4.0
# ߅	NKO DIGIT FIVE                                                  	Nd	5	5	5.0
# ߆	NKO DIGIT SIX                                                   	Nd	6	6	6.0
# ߇	NKO DIGIT SEVEN                                                 	Nd	7	7	7.0
# ߈	NKO DIGIT EIGHT                                                 	Nd	8	8	8.0
# ߉	NKO DIGIT NINE                                                  	Nd	9	9	9.0
# ०	DEVANAGARI DIGIT ZERO                                           	Nd	0	0	0.0
# १	DEVANAGARI DIGIT ONE                                            	Nd	1	1	1.0
# २	DEVANAGARI DIGIT TWO                                            	Nd	2	2	2.0
# ३	DEVANAGARI DIGIT THREE                                          	Nd	3	3	3.0
# ४	DEVANAGARI DIGIT FOUR                                           	Nd	4	4	4.0
# ५	DEVANAGARI DIGIT FIVE                                           	Nd	5	5	5.0
# ६	DEVANAGARI DIGIT SIX                                            	Nd	6	6	6.0
# ७	DEVANAGARI DIGIT SEVEN                                          	Nd	7	7	7.0
# ८	DEVANAGARI DIGIT EIGHT                                          	Nd	8	8	8.0
# ९	DEVANAGARI DIGIT NINE                                           	Nd	9	9	9.0
# ০	BENGALI DIGIT ZERO                                              	Nd	0	0	0.0
# ১	BENGALI DIGIT ONE                                               	Nd	1	1	1.0
# ২	BENGALI DIGIT TWO                                               	Nd	2	2	2.0
# ৩	BENGALI DIGIT THREE                                             	Nd	3	3	3.0
# ৪	BENGALI DIGIT FOUR                                              	Nd	4	4	4.0
# ৫	BENGALI DIGIT FIVE                                              	Nd	5	5	5.0
# ৬	BENGALI DIGIT SIX                                               	Nd	6	6	6.0
# ৭	BENGALI DIGIT SEVEN                                             	Nd	7	7	7.0
# ৮	BENGALI DIGIT EIGHT                                             	Nd	8	8	8.0
# ৯	BENGALI DIGIT NINE                                              	Nd	9	9	9.0
# ৴	BENGALI CURRENCY NUMERATOR ONE                                  	No	None	None	0.0625
# ৵	BENGALI CURRENCY NUMERATOR TWO                                  	No	None	None	0.125
# ৶	BENGALI CURRENCY NUMERATOR THREE                                	No	None	None	0.1875
# ৷	BENGALI CURRENCY NUMERATOR FOUR                                 	No	None	None	0.25
# ৸	BENGALI CURRENCY NUMERATOR ONE LESS THAN THE DENOMINATOR        	No	None	None	0.75
# ৹	BENGALI CURRENCY DENOMINATOR SIXTEEN                            	No	None	None	16.0
# ੦	GURMUKHI DIGIT ZERO                                             	Nd	0	0	0.0
# ੧	GURMUKHI DIGIT ONE                                              	Nd	1	1	1.0
# ੨	GURMUKHI DIGIT TWO                                              	Nd	2	2	2.0
# ੩	GURMUKHI DIGIT THREE                                            	Nd	3	3	3.0
# ੪	GURMUKHI DIGIT FOUR                                             	Nd	4	4	4.0
# ੫	GURMUKHI DIGIT FIVE                                             	Nd	5	5	5.0
# ੬	GURMUKHI DIGIT SIX                                              	Nd	6	6	6.0
# ੭	GURMUKHI DIGIT SEVEN                                            	Nd	7	7	7.0
# ੮	GURMUKHI DIGIT EIGHT                                            	Nd	8	8	8.0
# ੯	GURMUKHI DIGIT NINE                                             	Nd	9	9	9.0
# ૦	GUJARATI DIGIT ZERO                                             	Nd	0	0	0.0
# ૧	GUJARATI DIGIT ONE                                              	Nd	1	1	1.0
# ૨	GUJARATI DIGIT TWO                                              	Nd	2	2	2.0
# ૩	GUJARATI DIGIT THREE                                            	Nd	3	3	3.0
# ૪	GUJARATI DIGIT FOUR                                             	Nd	4	4	4.0
# ૫	GUJARATI DIGIT FIVE                                             	Nd	5	5	5.0
# ૬	GUJARATI DIGIT SIX                                              	Nd	6	6	6.0
# ૭	GUJARATI DIGIT SEVEN                                            	Nd	7	7	7.0
# ૮	GUJARATI DIGIT EIGHT                                            	Nd	8	8	8.0
# ૯	GUJARATI DIGIT NINE                                             	Nd	9	9	9.0
# ୦	ORIYA DIGIT ZERO                                                	Nd	0	0	0.0
# ୧	ORIYA DIGIT ONE                                                 	Nd	1	1	1.0
# ୨	ORIYA DIGIT TWO                                                 	Nd	2	2	2.0
# ୩	ORIYA DIGIT THREE                                               	Nd	3	3	3.0
# ୪	ORIYA DIGIT FOUR                                                	Nd	4	4	4.0
# ୫	ORIYA DIGIT FIVE                                                	Nd	5	5	5.0
# ୬	ORIYA DIGIT SIX                                                 	Nd	6	6	6.0
# ୭	ORIYA DIGIT SEVEN                                               	Nd	7	7	7.0
# ୮	ORIYA DIGIT EIGHT                                               	Nd	8	8	8.0
# ୯	ORIYA DIGIT NINE                                                	Nd	9	9	9.0
# ୲	ORIYA FRACTION ONE QUARTER                                      	No	None	None	0.25
# ୳	ORIYA FRACTION ONE HALF                                         	No	None	None	0.5
# ୴	ORIYA FRACTION THREE QUARTERS                                   	No	None	None	0.75
# ୵	ORIYA FRACTION ONE SIXTEENTH                                    	No	None	None	0.0625
# ୶	ORIYA FRACTION ONE EIGHTH                                       	No	None	None	0.125
# ୷	ORIYA FRACTION THREE SIXTEENTHS                                 	No	None	None	0.1875
# ௦	TAMIL DIGIT ZERO                                                	Nd	0	0	0.0
# ௧	TAMIL DIGIT ONE                                                 	Nd	1	1	1.0
# ௨	TAMIL DIGIT TWO                                                 	Nd	2	2	2.0
# ௩	TAMIL DIGIT THREE                                               	Nd	3	3	3.0
# ௪	TAMIL DIGIT FOUR                                                	Nd	4	4	4.0
# ௫	TAMIL DIGIT FIVE                                                	Nd	5	5	5.0
# ௬	TAMIL DIGIT SIX                                                 	Nd	6	6	6.0
# ௭	TAMIL DIGIT SEVEN                                               	Nd	7	7	7.0
# ௮	TAMIL DIGIT EIGHT                                               	Nd	8	8	8.0
# ௯	TAMIL DIGIT NINE                                                	Nd	9	9	9.0
# ௰	TAMIL NUMBER TEN                                                	No	None	None	10.0
# ௱	TAMIL NUMBER ONE HUNDRED                                        	No	None	None	100.0
# ௲	TAMIL NUMBER ONE THOUSAND                                       	No	None	None	1000.0
# ౦	TELUGU DIGIT ZERO                                               	Nd	0	0	0.0
# ౧	TELUGU DIGIT ONE                                                	Nd	1	1	1.0
# ౨	TELUGU DIGIT TWO                                                	Nd	2	2	2.0
# ౩	TELUGU DIGIT THREE                                              	Nd	3	3	3.0
# ౪	TELUGU DIGIT FOUR                                               	Nd	4	4	4.0
# ౫	TELUGU DIGIT FIVE                                               	Nd	5	5	5.0
# ౬	TELUGU DIGIT SIX                                                	Nd	6	6	6.0
# ౭	TELUGU DIGIT SEVEN                                              	Nd	7	7	7.0
# ౮	TELUGU DIGIT EIGHT                                              	Nd	8	8	8.0
# ౯	TELUGU DIGIT NINE                                               	Nd	9	9	9.0
# ౸	TELUGU FRACTION DIGIT ZERO FOR ODD POWERS OF FOUR               	No	None	None	0.0
# ౹	TELUGU FRACTION DIGIT ONE FOR ODD POWERS OF FOUR                	No	None	None	1.0
# ౺	TELUGU FRACTION DIGIT TWO FOR ODD POWERS OF FOUR                	No	None	None	2.0
# ౻	TELUGU FRACTION DIGIT THREE FOR ODD POWERS OF FOUR              	No	None	None	3.0
# ౼	TELUGU FRACTION DIGIT ONE FOR EVEN POWERS OF FOUR               	No	None	None	1.0
# ౽	TELUGU FRACTION DIGIT TWO FOR EVEN POWERS OF FOUR               	No	None	None	2.0
# ౾	TELUGU FRACTION DIGIT THREE FOR EVEN POWERS OF FOUR             	No	None	None	3.0
# ೦	KANNADA DIGIT ZERO                                              	Nd	0	0	0.0
# ೧	KANNADA DIGIT ONE                                               	Nd	1	1	1.0
# ೨	KANNADA DIGIT TWO                                               	Nd	2	2	2.0
# ೩	KANNADA DIGIT THREE                                             	Nd	3	3	3.0
# ೪	KANNADA DIGIT FOUR                                              	Nd	4	4	4.0
# ೫	KANNADA DIGIT FIVE                                              	Nd	5	5	5.0
# ೬	KANNADA DIGIT SIX                                               	Nd	6	6	6.0
# ೭	KANNADA DIGIT SEVEN                                             	Nd	7	7	7.0
# ೮	KANNADA DIGIT EIGHT                                             	Nd	8	8	8.0
# ೯	KANNADA DIGIT NINE                                              	Nd	9	9	9.0
# ൘	MALAYALAM FRACTION ONE ONE-HUNDRED-AND-SIXTIETH                 	No	None	None	0.00625
# ൙	MALAYALAM FRACTION ONE FORTIETH                                 	No	None	None	0.025
# ൚	MALAYALAM FRACTION THREE EIGHTIETHS                             	No	None	None	0.0375
# ൛	MALAYALAM FRACTION ONE TWENTIETH                                	No	None	None	0.05
# ൜	MALAYALAM FRACTION ONE TENTH                                    	No	None	None	0.1
# ൝	MALAYALAM FRACTION THREE TWENTIETHS                             	No	None	None	0.15
# ൞	MALAYALAM FRACTION ONE FIFTH                                    	No	None	None	0.2
# ൦	MALAYALAM DIGIT ZERO                                            	Nd	0	0	0.0
# ൧	MALAYALAM DIGIT ONE                                             	Nd	1	1	1.0
# ൨	MALAYALAM DIGIT TWO                                             	Nd	2	2	2.0
# ൩	MALAYALAM DIGIT THREE                                           	Nd	3	3	3.0
# ൪	MALAYALAM DIGIT FOUR                                            	Nd	4	4	4.0
# ൫	MALAYALAM DIGIT FIVE                                            	Nd	5	5	5.0
# ൬	MALAYALAM DIGIT SIX                                             	Nd	6	6	6.0
# ൭	MALAYALAM DIGIT SEVEN                                           	Nd	7	7	7.0
# ൮	MALAYALAM DIGIT EIGHT                                           	Nd	8	8	8.0
# ൯	MALAYALAM DIGIT NINE                                            	Nd	9	9	9.0
# ൰	MALAYALAM NUMBER TEN                                            	No	None	None	10.0
# ൱	MALAYALAM NUMBER ONE HUNDRED                                    	No	None	None	100.0
# ൲	MALAYALAM NUMBER ONE THOUSAND                                   	No	None	None	1000.0
# ൳	MALAYALAM FRACTION ONE QUARTER                                  	No	None	None	0.25
# ൴	MALAYALAM FRACTION ONE HALF                                     	No	None	None	0.5
# ൵	MALAYALAM FRACTION THREE QUARTERS                               	No	None	None	0.75
# ൶	MALAYALAM FRACTION ONE SIXTEENTH                                	No	None	None	0.0625
# ൷	MALAYALAM FRACTION ONE EIGHTH                                   	No	None	None	0.125
# ൸	MALAYALAM FRACTION THREE SIXTEENTHS                             	No	None	None	0.1875
# ෦	SINHALA LITH DIGIT ZERO                                         	Nd	0	0	0.0
# ෧	SINHALA LITH DIGIT ONE                                          	Nd	1	1	1.0
# ෨	SINHALA LITH DIGIT TWO                                          	Nd	2	2	2.0
# ෩	SINHALA LITH DIGIT THREE                                        	Nd	3	3	3.0
# ෪	SINHALA LITH DIGIT FOUR                                         	Nd	4	4	4.0
# ෫	SINHALA LITH DIGIT FIVE                                         	Nd	5	5	5.0
# ෬	SINHALA LITH DIGIT SIX                                          	Nd	6	6	6.0
# ෭	SINHALA LITH DIGIT SEVEN                                        	Nd	7	7	7.0
# ෮	SINHALA LITH DIGIT EIGHT                                        	Nd	8	8	8.0
# ෯	SINHALA LITH DIGIT NINE                                         	Nd	9	9	9.0
# ๐	THAI DIGIT ZERO                                                 	Nd	0	0	0.0
# ๑	THAI DIGIT ONE                                                  	Nd	1	1	1.0
# ๒	THAI DIGIT TWO                                                  	Nd	2	2	2.0
# ๓	THAI DIGIT THREE                                                	Nd	3	3	3.0
# ๔	THAI DIGIT FOUR                                                 	Nd	4	4	4.0
# ๕	THAI DIGIT FIVE                                                 	Nd	5	5	5.0
# ๖	THAI DIGIT SIX                                                  	Nd	6	6	6.0
# ๗	THAI DIGIT SEVEN                                                	Nd	7	7	7.0
# ๘	THAI DIGIT EIGHT                                                	Nd	8	8	8.0
# ๙	THAI DIGIT NINE                                                 	Nd	9	9	9.0
# ໐	LAO DIGIT ZERO                                                  	Nd	0	0	0.0
# ໑	LAO DIGIT ONE                                                   	Nd	1	1	1.0
# ໒	LAO DIGIT TWO                                                   	Nd	2	2	2.0
# ໓	LAO DIGIT THREE                                                 	Nd	3	3	3.0
# ໔	LAO DIGIT FOUR                                                  	Nd	4	4	4.0
# ໕	LAO DIGIT FIVE                                                  	Nd	5	5	5.0
# ໖	LAO DIGIT SIX                                                   	Nd	6	6	6.0
# ໗	LAO DIGIT SEVEN                                                 	Nd	7	7	7.0
# ໘	LAO DIGIT EIGHT                                                 	Nd	8	8	8.0
# ໙	LAO DIGIT NINE                                                  	Nd	9	9	9.0
# ༠	TIBETAN DIGIT ZERO                                              	Nd	0	0	0.0
# ༡	TIBETAN DIGIT ONE                                               	Nd	1	1	1.0
# ༢	TIBETAN DIGIT TWO                                               	Nd	2	2	2.0
# ༣	TIBETAN DIGIT THREE                                             	Nd	3	3	3.0
# ༤	TIBETAN DIGIT FOUR                                              	Nd	4	4	4.0
# ༥	TIBETAN DIGIT FIVE                                              	Nd	5	5	5.0
# ༦	TIBETAN DIGIT SIX                                               	Nd	6	6	6.0
# ༧	TIBETAN DIGIT SEVEN                                             	Nd	7	7	7.0
# ༨	TIBETAN DIGIT EIGHT                                             	Nd	8	8	8.0
# ༩	TIBETAN DIGIT NINE                                              	Nd	9	9	9.0
# ༪	TIBETAN DIGIT HALF ONE                                          	No	None	None	0.5
# ༫	TIBETAN DIGIT HALF TWO                                          	No	None	None	1.5
# ༬	TIBETAN DIGIT HALF THREE                                        	No	None	None	2.5
# ༭	TIBETAN DIGIT HALF FOUR                                         	No	None	None	3.5
# ༮	TIBETAN DIGIT HALF FIVE                                         	No	None	None	4.5
# ༯	TIBETAN DIGIT HALF SIX                                          	No	None	None	5.5
# ༰	TIBETAN DIGIT HALF SEVEN                                        	No	None	None	6.5
# ༱	TIBETAN DIGIT HALF EIGHT                                        	No	None	None	7.5
# ༲	TIBETAN DIGIT HALF NINE                                         	No	None	None	8.5
# ༳	TIBETAN DIGIT HALF ZERO                                         	No	None	None	-0.5
# ၀	MYANMAR DIGIT ZERO                                              	Nd	0	0	0.0
# ၁	MYANMAR DIGIT ONE                                               	Nd	1	1	1.0
# ၂	MYANMAR DIGIT TWO                                               	Nd	2	2	2.0
# ၃	MYANMAR DIGIT THREE                                             	Nd	3	3	3.0
# ၄	MYANMAR DIGIT FOUR                                              	Nd	4	4	4.0
# ၅	MYANMAR DIGIT FIVE                                              	Nd	5	5	5.0
# ၆	MYANMAR DIGIT SIX                                               	Nd	6	6	6.0
# ၇	MYANMAR DIGIT SEVEN                                             	Nd	7	7	7.0
# ၈	MYANMAR DIGIT EIGHT                                             	Nd	8	8	8.0
# ၉	MYANMAR DIGIT NINE                                              	Nd	9	9	9.0
# ႐	MYANMAR SHAN DIGIT ZERO                                         	Nd	0	0	0.0
# ႑	MYANMAR SHAN DIGIT ONE                                          	Nd	1	1	1.0
# ႒	MYANMAR SHAN DIGIT TWO                                          	Nd	2	2	2.0
# ႓	MYANMAR SHAN DIGIT THREE                                        	Nd	3	3	3.0
# ႔	MYANMAR SHAN DIGIT FOUR                                         	Nd	4	4	4.0
# ႕	MYANMAR SHAN DIGIT FIVE                                         	Nd	5	5	5.0
# ႖	MYANMAR SHAN DIGIT SIX                                          	Nd	6	6	6.0
# ႗	MYANMAR SHAN DIGIT SEVEN                                        	Nd	7	7	7.0
# ႘	MYANMAR SHAN DIGIT EIGHT                                        	Nd	8	8	8.0
# ႙	MYANMAR SHAN DIGIT NINE                                         	Nd	9	9	9.0
# ፩	ETHIOPIC DIGIT ONE                                              	No	None	1	1.0
# ፪	ETHIOPIC DIGIT TWO                                              	No	None	2	2.0
# ፫	ETHIOPIC DIGIT THREE                                            	No	None	3	3.0
# ፬	ETHIOPIC DIGIT FOUR                                             	No	None	4	4.0
# ፭	ETHIOPIC DIGIT FIVE                                             	No	None	5	5.0
# ፮	ETHIOPIC DIGIT SIX                                              	No	None	6	6.0
# ፯	ETHIOPIC DIGIT SEVEN                                            	No	None	7	7.0
# ፰	ETHIOPIC DIGIT EIGHT                                            	No	None	8	8.0
# ፱	ETHIOPIC DIGIT NINE                                             	No	None	9	9.0
# ፲	ETHIOPIC NUMBER TEN                                             	No	None	None	10.0
# ፳	ETHIOPIC NUMBER TWENTY                                          	No	None	None	20.0
# ፴	ETHIOPIC NUMBER THIRTY                                          	No	None	None	30.0
# ፵	ETHIOPIC NUMBER FORTY                                           	No	None	None	40.0
# ፶	ETHIOPIC NUMBER FIFTY                                           	No	None	None	50.0
# ፷	ETHIOPIC NUMBER SIXTY                                           	No	None	None	60.0
# ፸	ETHIOPIC NUMBER SEVENTY                                         	No	None	None	70.0
# ፹	ETHIOPIC NUMBER EIGHTY                                          	No	None	None	80.0
# ፺	ETHIOPIC NUMBER NINETY                                          	No	None	None	90.0
# ፻	ETHIOPIC NUMBER HUNDRED                                         	No	None	None	100.0
# ፼	ETHIOPIC NUMBER TEN THOUSAND                                    	No	None	None	10000.0
# ᛮ	RUNIC ARLAUG SYMBOL                                             	Nl	None	None	17.0
# ᛯ	RUNIC TVIMADUR SYMBOL                                           	Nl	None	None	18.0
# ᛰ	RUNIC BELGTHOR SYMBOL                                           	Nl	None	None	19.0
# ០	KHMER DIGIT ZERO                                                	Nd	0	0	0.0
# ១	KHMER DIGIT ONE                                                 	Nd	1	1	1.0
# ២	KHMER DIGIT TWO                                                 	Nd	2	2	2.0
# ៣	KHMER DIGIT THREE                                               	Nd	3	3	3.0
# ៤	KHMER DIGIT FOUR                                                	Nd	4	4	4.0
# ៥	KHMER DIGIT FIVE                                                	Nd	5	5	5.0
# ៦	KHMER DIGIT SIX                                                 	Nd	6	6	6.0
# ៧	KHMER DIGIT SEVEN                                               	Nd	7	7	7.0
# ៨	KHMER DIGIT EIGHT                                               	Nd	8	8	8.0
# ៩	KHMER DIGIT NINE                                                	Nd	9	9	9.0
# ៰	KHMER SYMBOL LEK ATTAK SON                                      	No	None	None	0.0
# ៱	KHMER SYMBOL LEK ATTAK MUOY                                     	No	None	None	1.0
# ៲	KHMER SYMBOL LEK ATTAK PII                                      	No	None	None	2.0
# ៳	KHMER SYMBOL LEK ATTAK BEI                                      	No	None	None	3.0
# ៴	KHMER SYMBOL LEK ATTAK BUON                                     	No	None	None	4.0
# ៵	KHMER SYMBOL LEK ATTAK PRAM                                     	No	None	None	5.0
# ៶	KHMER SYMBOL LEK ATTAK PRAM-MUOY                                	No	None	None	6.0
# ៷	KHMER SYMBOL LEK ATTAK PRAM-PII                                 	No	None	None	7.0
# ៸	KHMER SYMBOL LEK ATTAK PRAM-BEI                                 	No	None	None	8.0
# ៹	KHMER SYMBOL LEK ATTAK PRAM-BUON                                	No	None	None	9.0
# ᠐	MONGOLIAN DIGIT ZERO                                            	Nd	0	0	0.0
# ᠑	MONGOLIAN DIGIT ONE                                             	Nd	1	1	1.0
# ᠒	MONGOLIAN DIGIT TWO                                             	Nd	2	2	2.0
# ᠓	MONGOLIAN DIGIT THREE                                           	Nd	3	3	3.0
# ᠔	MONGOLIAN DIGIT FOUR                                            	Nd	4	4	4.0
# ᠕	MONGOLIAN DIGIT FIVE                                            	Nd	5	5	5.0
# ᠖	MONGOLIAN DIGIT SIX                                             	Nd	6	6	6.0
# ᠗	MONGOLIAN DIGIT SEVEN                                           	Nd	7	7	7.0
# ᠘	MONGOLIAN DIGIT EIGHT                                           	Nd	8	8	8.0
# ᠙	MONGOLIAN DIGIT NINE                                            	Nd	9	9	9.0
# ᥆	LIMBU DIGIT ZERO                                                	Nd	0	0	0.0
# ᥇	LIMBU DIGIT ONE                                                 	Nd	1	1	1.0
# ᥈	LIMBU DIGIT TWO                                                 	Nd	2	2	2.0
# ᥉	LIMBU DIGIT THREE                                               	Nd	3	3	3.0
# ᥊	LIMBU DIGIT FOUR                                                	Nd	4	4	4.0
# ᥋	LIMBU DIGIT FIVE                                                	Nd	5	5	5.0
# ᥌	LIMBU DIGIT SIX                                                 	Nd	6	6	6.0
# ᥍	LIMBU DIGIT SEVEN                                               	Nd	7	7	7.0
# ᥎	LIMBU DIGIT EIGHT                                               	Nd	8	8	8.0
# ᥏	LIMBU DIGIT NINE                                                	Nd	9	9	9.0
# ᧐	NEW TAI LUE DIGIT ZERO                                          	Nd	0	0	0.0
# ᧑	NEW TAI LUE DIGIT ONE                                           	Nd	1	1	1.0
# ᧒	NEW TAI LUE DIGIT TWO                                           	Nd	2	2	2.0
# ᧓	NEW TAI LUE DIGIT THREE                                         	Nd	3	3	3.0
# ᧔	NEW TAI LUE DIGIT FOUR                                          	Nd	4	4	4.0
# ᧕	NEW TAI LUE DIGIT FIVE                                          	Nd	5	5	5.0
# ᧖	NEW TAI LUE DIGIT SIX                                           	Nd	6	6	6.0
# ᧗	NEW TAI LUE DIGIT SEVEN                                         	Nd	7	7	7.0
# ᧘	NEW TAI LUE DIGIT EIGHT                                         	Nd	8	8	8.0
# ᧙	NEW TAI LUE DIGIT NINE                                          	Nd	9	9	9.0
# ᧚	NEW TAI LUE THAM DIGIT ONE                                      	No	None	1	1.0
# ᪀	TAI THAM HORA DIGIT ZERO                                        	Nd	0	0	0.0
# ᪁	TAI THAM HORA DIGIT ONE                                         	Nd	1	1	1.0
# ᪂	TAI THAM HORA DIGIT TWO                                         	Nd	2	2	2.0
# ᪃	TAI THAM HORA DIGIT THREE                                       	Nd	3	3	3.0
# ᪄	TAI THAM HORA DIGIT FOUR                                        	Nd	4	4	4.0
# ᪅	TAI THAM HORA DIGIT FIVE                                        	Nd	5	5	5.0
# ᪆	TAI THAM HORA DIGIT SIX                                         	Nd	6	6	6.0
# ᪇	TAI THAM HORA DIGIT SEVEN                                       	Nd	7	7	7.0
# ᪈	TAI THAM HORA DIGIT EIGHT                                       	Nd	8	8	8.0
# ᪉	TAI THAM HORA DIGIT NINE                                        	Nd	9	9	9.0
# ᪐	TAI THAM THAM DIGIT ZERO                                        	Nd	0	0	0.0
# ᪑	TAI THAM THAM DIGIT ONE                                         	Nd	1	1	1.0
# ᪒	TAI THAM THAM DIGIT TWO                                         	Nd	2	2	2.0
# ᪓	TAI THAM THAM DIGIT THREE                                       	Nd	3	3	3.0
# ᪔	TAI THAM THAM DIGIT FOUR                                        	Nd	4	4	4.0
# ᪕	TAI THAM THAM DIGIT FIVE                                        	Nd	5	5	5.0
# ᪖	TAI THAM THAM DIGIT SIX                                         	Nd	6	6	6.0
# ᪗	TAI THAM THAM DIGIT SEVEN                                       	Nd	7	7	7.0
# ᪘	TAI THAM THAM DIGIT EIGHT                                       	Nd	8	8	8.0
# ᪙	TAI THAM THAM DIGIT NINE                                        	Nd	9	9	9.0
# ᭐	BALINESE DIGIT ZERO                                             	Nd	0	0	0.0
# ᭑	BALINESE DIGIT ONE                                              	Nd	1	1	1.0
# ᭒	BALINESE DIGIT TWO                                              	Nd	2	2	2.0
# ᭓	BALINESE DIGIT THREE                                            	Nd	3	3	3.0
# ᭔	BALINESE DIGIT FOUR                                             	Nd	4	4	4.0
# ᭕	BALINESE DIGIT FIVE                                             	Nd	5	5	5.0
# ᭖	BALINESE DIGIT SIX                                              	Nd	6	6	6.0
# ᭗	BALINESE DIGIT SEVEN                                            	Nd	7	7	7.0
# ᭘	BALINESE DIGIT EIGHT                                            	Nd	8	8	8.0
# ᭙	BALINESE DIGIT NINE                                             	Nd	9	9	9.0
# ᮰	SUNDANESE DIGIT ZERO                                            	Nd	0	0	0.0
# ᮱	SUNDANESE DIGIT ONE                                             	Nd	1	1	1.0
# ᮲	SUNDANESE DIGIT TWO                                             	Nd	2	2	2.0
# ᮳	SUNDANESE DIGIT THREE                                           	Nd	3	3	3.0
# ᮴	SUNDANESE DIGIT FOUR                                            	Nd	4	4	4.0
# ᮵	SUNDANESE DIGIT FIVE                                            	Nd	5	5	5.0
# ᮶	SUNDANESE DIGIT SIX                                             	Nd	6	6	6.0
# ᮷	SUNDANESE DIGIT SEVEN                                           	Nd	7	7	7.0
# ᮸	SUNDANESE DIGIT EIGHT                                           	Nd	8	8	8.0
# ᮹	SUNDANESE DIGIT NINE                                            	Nd	9	9	9.0
# ᱀	LEPCHA DIGIT ZERO                                               	Nd	0	0	0.0
# ᱁	LEPCHA DIGIT ONE                                                	Nd	1	1	1.0
# ᱂	LEPCHA DIGIT TWO                                                	Nd	2	2	2.0
# ᱃	LEPCHA DIGIT THREE                                              	Nd	3	3	3.0
# ᱄	LEPCHA DIGIT FOUR                                               	Nd	4	4	4.0
# ᱅	LEPCHA DIGIT FIVE                                               	Nd	5	5	5.0
# ᱆	LEPCHA DIGIT SIX                                                	Nd	6	6	6.0
# ᱇	LEPCHA DIGIT SEVEN                                              	Nd	7	7	7.0
# ᱈	LEPCHA DIGIT EIGHT                                              	Nd	8	8	8.0
# ᱉	LEPCHA DIGIT NINE                                               	Nd	9	9	9.0
# ᱐	OL CHIKI DIGIT ZERO                                             	Nd	0	0	0.0
# ᱑	OL CHIKI DIGIT ONE                                              	Nd	1	1	1.0
# ᱒	OL CHIKI DIGIT TWO                                              	Nd	2	2	2.0
# ᱓	OL CHIKI DIGIT THREE                                            	Nd	3	3	3.0
# ᱔	OL CHIKI DIGIT FOUR                                             	Nd	4	4	4.0
# ᱕	OL CHIKI DIGIT FIVE                                             	Nd	5	5	5.0
# ᱖	OL CHIKI DIGIT SIX                                              	Nd	6	6	6.0
# ᱗	OL CHIKI DIGIT SEVEN                                            	Nd	7	7	7.0
# ᱘	OL CHIKI DIGIT EIGHT                                            	Nd	8	8	8.0
# ᱙	OL CHIKI DIGIT NINE                                             	Nd	9	9	9.0
# ⁰	SUPERSCRIPT ZERO                                                	No	None	0	0.0
# ⁴	SUPERSCRIPT FOUR                                                	No	None	4	4.0
# ⁵	SUPERSCRIPT FIVE                                                	No	None	5	5.0
# ⁶	SUPERSCRIPT SIX                                                 	No	None	6	6.0
# ⁷	SUPERSCRIPT SEVEN                                               	No	None	7	7.0
# ⁸	SUPERSCRIPT EIGHT                                               	No	None	8	8.0
# ⁹	SUPERSCRIPT NINE                                                	No	None	9	9.0
# ₀	SUBSCRIPT ZERO                                                  	No	None	0	0.0
# ₁	SUBSCRIPT ONE                                                   	No	None	1	1.0
# ₂	SUBSCRIPT TWO                                                   	No	None	2	2.0
# ₃	SUBSCRIPT THREE                                                 	No	None	3	3.0
# ₄	SUBSCRIPT FOUR                                                  	No	None	4	4.0
# ₅	SUBSCRIPT FIVE                                                  	No	None	5	5.0
# ₆	SUBSCRIPT SIX                                                   	No	None	6	6.0
# ₇	SUBSCRIPT SEVEN                                                 	No	None	7	7.0
# ₈	SUBSCRIPT EIGHT                                                 	No	None	8	8.0
# ₉	SUBSCRIPT NINE                                                  	No	None	9	9.0
# ⅐	VULGAR FRACTION ONE SEVENTH                                     	No	None	None	0.14285714285714285
# ⅑	VULGAR FRACTION ONE NINTH                                       	No	None	None	0.1111111111111111
# ⅒	VULGAR FRACTION ONE TENTH                                       	No	None	None	0.1
# ⅓	VULGAR FRACTION ONE THIRD                                       	No	None	None	0.3333333333333333
# ⅔	VULGAR FRACTION TWO THIRDS                                      	No	None	None	0.6666666666666666
# ⅕	VULGAR FRACTION ONE FIFTH                                       	No	None	None	0.2
# ⅖	VULGAR FRACTION TWO FIFTHS                                      	No	None	None	0.4
# ⅗	VULGAR FRACTION THREE FIFTHS                                    	No	None	None	0.6
# ⅘	VULGAR FRACTION FOUR FIFTHS                                     	No	None	None	0.8
# ⅙	VULGAR FRACTION ONE SIXTH                                       	No	None	None	0.16666666666666666
# ⅚	VULGAR FRACTION FIVE SIXTHS                                     	No	None	None	0.8333333333333334
# ⅛	VULGAR FRACTION ONE EIGHTH                                      	No	None	None	0.125
# ⅜	VULGAR FRACTION THREE EIGHTHS                                   	No	None	None	0.375
# ⅝	VULGAR FRACTION FIVE EIGHTHS                                    	No	None	None	0.625
# ⅞	VULGAR FRACTION SEVEN EIGHTHS                                   	No	None	None	0.875
# ⅟	FRACTION NUMERATOR ONE                                          	No	None	None	1.0
# Ⅰ	ROMAN NUMERAL ONE                                               	Nl	None	None	1.0
# Ⅱ	ROMAN NUMERAL TWO                                               	Nl	None	None	2.0
# Ⅲ	ROMAN NUMERAL THREE                                             	Nl	None	None	3.0
# Ⅳ	ROMAN NUMERAL FOUR                                              	Nl	None	None	4.0
# Ⅴ	ROMAN NUMERAL FIVE                                              	Nl	None	None	5.0
# Ⅵ	ROMAN NUMERAL SIX                                               	Nl	None	None	6.0
# Ⅶ	ROMAN NUMERAL SEVEN                                             	Nl	None	None	7.0
# Ⅷ	ROMAN NUMERAL EIGHT                                             	Nl	None	None	8.0
# Ⅸ	ROMAN NUMERAL NINE                                              	Nl	None	None	9.0
# Ⅹ	ROMAN NUMERAL TEN                                               	Nl	None	None	10.0
# Ⅺ	ROMAN NUMERAL ELEVEN                                            	Nl	None	None	11.0
# Ⅻ	ROMAN NUMERAL TWELVE                                            	Nl	None	None	12.0
# Ⅼ	ROMAN NUMERAL FIFTY                                             	Nl	None	None	50.0
# Ⅽ	ROMAN NUMERAL ONE HUNDRED                                       	Nl	None	None	100.0
# Ⅾ	ROMAN NUMERAL FIVE HUNDRED                                      	Nl	None	None	500.0
# Ⅿ	ROMAN NUMERAL ONE THOUSAND                                      	Nl	None	None	1000.0
# ⅰ	SMALL ROMAN NUMERAL ONE                                         	Nl	None	None	1.0
# ⅱ	SMALL ROMAN NUMERAL TWO                                         	Nl	None	None	2.0
# ⅲ	SMALL ROMAN NUMERAL THREE                                       	Nl	None	None	3.0
# ⅳ	SMALL ROMAN NUMERAL FOUR                                        	Nl	None	None	4.0
# ⅴ	SMALL ROMAN NUMERAL FIVE                                        	Nl	None	None	5.0
# ⅵ	SMALL ROMAN NUMERAL SIX                                         	Nl	None	None	6.0
# ⅶ	SMALL ROMAN NUMERAL SEVEN                                       	Nl	None	None	7.0
# ⅷ	SMALL ROMAN NUMERAL EIGHT                                       	Nl	None	None	8.0
# ⅸ	SMALL ROMAN NUMERAL NINE                                        	Nl	None	None	9.0
# ⅹ	SMALL ROMAN NUMERAL TEN                                         	Nl	None	None	10.0
# ⅺ	SMALL ROMAN NUMERAL ELEVEN                                      	Nl	None	None	11.0
# ⅻ	SMALL ROMAN NUMERAL TWELVE                                      	Nl	None	None	12.0
# ⅼ	SMALL ROMAN NUMERAL FIFTY                                       	Nl	None	None	50.0
# ⅽ	SMALL ROMAN NUMERAL ONE HUNDRED                                 	Nl	None	None	100.0
# ⅾ	SMALL ROMAN NUMERAL FIVE HUNDRED                                	Nl	None	None	500.0
# ⅿ	SMALL ROMAN NUMERAL ONE THOUSAND                                	Nl	None	None	1000.0
# ↀ	ROMAN NUMERAL ONE THOUSAND C D                                  	Nl	None	None	1000.0
# ↁ	ROMAN NUMERAL FIVE THOUSAND                                     	Nl	None	None	5000.0
# ↂ	ROMAN NUMERAL TEN THOUSAND                                      	Nl	None	None	10000.0
# ↅ	ROMAN NUMERAL SIX LATE FORM                                     	Nl	None	None	6.0
# ↆ	ROMAN NUMERAL FIFTY EARLY FORM                                  	Nl	None	None	50.0
# ↇ	ROMAN NUMERAL FIFTY THOUSAND                                    	Nl	None	None	50000.0
# ↈ	ROMAN NUMERAL ONE HUNDRED THOUSAND                              	Nl	None	None	100000.0
# ↉	VULGAR FRACTION ZERO THIRDS                                     	No	None	None	0.0
# ①	CIRCLED DIGIT ONE                                               	No	None	1	1.0
# ②	CIRCLED DIGIT TWO                                               	No	None	2	2.0
# ③	CIRCLED DIGIT THREE                                             	No	None	3	3.0
# ④	CIRCLED DIGIT FOUR                                              	No	None	4	4.0
# ⑤	CIRCLED DIGIT FIVE                                              	No	None	5	5.0
# ⑥	CIRCLED DIGIT SIX                                               	No	None	6	6.0
# ⑦	CIRCLED DIGIT SEVEN                                             	No	None	7	7.0
# ⑧	CIRCLED DIGIT EIGHT                                             	No	None	8	8.0
# ⑨	CIRCLED DIGIT NINE                                              	No	None	9	9.0
# ⑩	CIRCLED NUMBER TEN                                              	No	None	None	10.0
# ⑪	CIRCLED NUMBER ELEVEN                                           	No	None	None	11.0
# ⑫	CIRCLED NUMBER TWELVE                                           	No	None	None	12.0
# ⑬	CIRCLED NUMBER THIRTEEN                                         	No	None	None	13.0
# ⑭	CIRCLED NUMBER FOURTEEN                                         	No	None	None	14.0
# ⑮	CIRCLED NUMBER FIFTEEN                                          	No	None	None	15.0
# ⑯	CIRCLED NUMBER SIXTEEN                                          	No	None	None	16.0
# ⑰	CIRCLED NUMBER SEVENTEEN                                        	No	None	None	17.0
# ⑱	CIRCLED NUMBER EIGHTEEN                                         	No	None	None	18.0
# ⑲	CIRCLED NUMBER NINETEEN                                         	No	None	None	19.0
# ⑳	CIRCLED NUMBER TWENTY                                           	No	None	None	20.0
# ⑴	PARENTHESIZED DIGIT ONE                                         	No	None	1	1.0
# ⑵	PARENTHESIZED DIGIT TWO                                         	No	None	2	2.0
# ⑶	PARENTHESIZED DIGIT THREE                                       	No	None	3	3.0
# ⑷	PARENTHESIZED DIGIT FOUR                                        	No	None	4	4.0
# ⑸	PARENTHESIZED DIGIT FIVE                                        	No	None	5	5.0
# ⑹	PARENTHESIZED DIGIT SIX                                         	No	None	6	6.0
# ⑺	PARENTHESIZED DIGIT SEVEN                                       	No	None	7	7.0
# ⑻	PARENTHESIZED DIGIT EIGHT                                       	No	None	8	8.0
# ⑼	PARENTHESIZED DIGIT NINE                                        	No	None	9	9.0
# ⑽	PARENTHESIZED NUMBER TEN                                        	No	None	None	10.0
# ⑾	PARENTHESIZED NUMBER ELEVEN                                     	No	None	None	11.0
# ⑿	PARENTHESIZED NUMBER TWELVE                                     	No	None	None	12.0
# ⒀	PARENTHESIZED NUMBER THIRTEEN                                   	No	None	None	13.0
# ⒁	PARENTHESIZED NUMBER FOURTEEN                                   	No	None	None	14.0
# ⒂	PARENTHESIZED NUMBER FIFTEEN                                    	No	None	None	15.0
# ⒃	PARENTHESIZED NUMBER SIXTEEN                                    	No	None	None	16.0
# ⒄	PARENTHESIZED NUMBER SEVENTEEN                                  	No	None	None	17.0
# ⒅	PARENTHESIZED NUMBER EIGHTEEN                                   	No	None	None	18.0
# ⒆	PARENTHESIZED NUMBER NINETEEN                                   	No	None	None	19.0
# ⒇	PARENTHESIZED NUMBER TWENTY                                     	No	None	None	20.0
# ⒈	DIGIT ONE FULL STOP                                             	No	None	1	1.0
# ⒉	DIGIT TWO FULL STOP                                             	No	None	2	2.0
# ⒊	DIGIT THREE FULL STOP                                           	No	None	3	3.0
# ⒋	DIGIT FOUR FULL STOP                                            	No	None	4	4.0
# ⒌	DIGIT FIVE FULL STOP                                            	No	None	5	5.0
# ⒍	DIGIT SIX FULL STOP                                             	No	None	6	6.0
# ⒎	DIGIT SEVEN FULL STOP                                           	No	None	7	7.0
# ⒏	DIGIT EIGHT FULL STOP                                           	No	None	8	8.0
# ⒐	DIGIT NINE FULL STOP                                            	No	None	9	9.0
# ⒑	NUMBER TEN FULL STOP                                            	No	None	None	10.0
# ⒒	NUMBER ELEVEN FULL STOP                                         	No	None	None	11.0
# ⒓	NUMBER TWELVE FULL STOP                                         	No	None	None	12.0
# ⒔	NUMBER THIRTEEN FULL STOP                                       	No	None	None	13.0
# ⒕	NUMBER FOURTEEN FULL STOP                                       	No	None	None	14.0
# ⒖	NUMBER FIFTEEN FULL STOP                                        	No	None	None	15.0
# ⒗	NUMBER SIXTEEN FULL STOP                                        	No	None	None	16.0
# ⒘	NUMBER SEVENTEEN FULL STOP                                      	No	None	None	17.0
# ⒙	NUMBER EIGHTEEN FULL STOP                                       	No	None	None	18.0
# ⒚	NUMBER NINETEEN FULL STOP                                       	No	None	None	19.0
# ⒛	NUMBER TWENTY FULL STOP                                         	No	None	None	20.0
# ⓪	CIRCLED DIGIT ZERO                                              	No	None	0	0.0
# ⓫	NEGATIVE CIRCLED NUMBER ELEVEN                                  	No	None	None	11.0
# ⓬	NEGATIVE CIRCLED NUMBER TWELVE                                  	No	None	None	12.0
# ⓭	NEGATIVE CIRCLED NUMBER THIRTEEN                                	No	None	None	13.0
# ⓮	NEGATIVE CIRCLED NUMBER FOURTEEN                                	No	None	None	14.0
# ⓯	NEGATIVE CIRCLED NUMBER FIFTEEN                                 	No	None	None	15.0
# ⓰	NEGATIVE CIRCLED NUMBER SIXTEEN                                 	No	None	None	16.0
# ⓱	NEGATIVE CIRCLED NUMBER SEVENTEEN                               	No	None	None	17.0
# ⓲	NEGATIVE CIRCLED NUMBER EIGHTEEN                                	No	None	None	18.0
# ⓳	NEGATIVE CIRCLED NUMBER NINETEEN                                	No	None	None	19.0
# ⓴	NEGATIVE CIRCLED NUMBER TWENTY                                  	No	None	None	20.0
# ⓵	DOUBLE CIRCLED DIGIT ONE                                        	No	None	1	1.0
# ⓶	DOUBLE CIRCLED DIGIT TWO                                        	No	None	2	2.0
# ⓷	DOUBLE CIRCLED DIGIT THREE                                      	No	None	3	3.0
# ⓸	DOUBLE CIRCLED DIGIT FOUR                                       	No	None	4	4.0
# ⓹	DOUBLE CIRCLED DIGIT FIVE                                       	No	None	5	5.0
# ⓺	DOUBLE CIRCLED DIGIT SIX                                        	No	None	6	6.0
# ⓻	DOUBLE CIRCLED DIGIT SEVEN                                      	No	None	7	7.0
# ⓼	DOUBLE CIRCLED DIGIT EIGHT                                      	No	None	8	8.0
# ⓽	DOUBLE CIRCLED DIGIT NINE                                       	No	None	9	9.0
# ⓾	DOUBLE CIRCLED NUMBER TEN                                       	No	None	None	10.0
# ⓿	NEGATIVE CIRCLED DIGIT ZERO                                     	No	None	0	0.0
# ❶	DINGBAT NEGATIVE CIRCLED DIGIT ONE                              	No	None	1	1.0
# ❷	DINGBAT NEGATIVE CIRCLED DIGIT TWO                              	No	None	2	2.0
# ❸	DINGBAT NEGATIVE CIRCLED DIGIT THREE                            	No	None	3	3.0
# ❹	DINGBAT NEGATIVE CIRCLED DIGIT FOUR                             	No	None	4	4.0
# ❺	DINGBAT NEGATIVE CIRCLED DIGIT FIVE                             	No	None	5	5.0
# ❻	DINGBAT NEGATIVE CIRCLED DIGIT SIX                              	No	None	6	6.0
# ❼	DINGBAT NEGATIVE CIRCLED DIGIT SEVEN                            	No	None	7	7.0
# ❽	DINGBAT NEGATIVE CIRCLED DIGIT EIGHT                            	No	None	8	8.0
# ❾	DINGBAT NEGATIVE CIRCLED DIGIT NINE                             	No	None	9	9.0
# ❿	DINGBAT NEGATIVE CIRCLED NUMBER TEN                             	No	None	None	10.0
# ➀	DINGBAT CIRCLED SANS-SERIF DIGIT ONE                            	No	None	1	1.0
# ➁	DINGBAT CIRCLED SANS-SERIF DIGIT TWO                            	No	None	2	2.0
# ➂	DINGBAT CIRCLED SANS-SERIF DIGIT THREE                          	No	None	3	3.0
# ➃	DINGBAT CIRCLED SANS-SERIF DIGIT FOUR                           	No	None	4	4.0
# ➄	DINGBAT CIRCLED SANS-SERIF DIGIT FIVE                           	No	None	5	5.0
# ➅	DINGBAT CIRCLED SANS-SERIF DIGIT SIX                            	No	None	6	6.0
# ➆	DINGBAT CIRCLED SANS-SERIF DIGIT SEVEN                          	No	None	7	7.0
# ➇	DINGBAT CIRCLED SANS-SERIF DIGIT EIGHT                          	No	None	8	8.0
# ➈	DINGBAT CIRCLED SANS-SERIF DIGIT NINE                           	No	None	9	9.0
# ➉	DINGBAT CIRCLED SANS-SERIF NUMBER TEN                           	No	None	None	10.0
# ➊	DINGBAT NEGATIVE CIRCLED SANS-SERIF DIGIT ONE                   	No	None	1	1.0
# ➋	DINGBAT NEGATIVE CIRCLED SANS-SERIF DIGIT TWO                   	No	None	2	2.0
# ➌	DINGBAT NEGATIVE CIRCLED SANS-SERIF DIGIT THREE                 	No	None	3	3.0
# ➍	DINGBAT NEGATIVE CIRCLED SANS-SERIF DIGIT FOUR                  	No	None	4	4.0
# ➎	DINGBAT NEGATIVE CIRCLED SANS-SERIF DIGIT FIVE                  	No	None	5	5.0
# ➏	DINGBAT NEGATIVE CIRCLED SANS-SERIF DIGIT SIX                   	No	None	6	6.0
# ➐	DINGBAT NEGATIVE CIRCLED SANS-SERIF DIGIT SEVEN                 	No	None	7	7.0
# ➑	DINGBAT NEGATIVE CIRCLED SANS-SERIF DIGIT EIGHT                 	No	None	8	8.0
# ➒	DINGBAT NEGATIVE CIRCLED SANS-SERIF DIGIT NINE                  	No	None	9	9.0
# ➓	DINGBAT NEGATIVE CIRCLED SANS-SERIF NUMBER TEN                  	No	None	None	10.0
# ⳽	COPTIC FRACTION ONE HALF                                        	No	None	None	0.5
# 〇	IDEOGRAPHIC NUMBER ZERO                                         	Nl	None	None	0.0
# 〡	HANGZHOU NUMERAL ONE                                            	Nl	None	None	1.0
# 〢	HANGZHOU NUMERAL TWO                                            	Nl	None	None	2.0
# 〣	HANGZHOU NUMERAL THREE                                          	Nl	None	None	3.0
# 〤	HANGZHOU NUMERAL FOUR                                           	Nl	None	None	4.0
# 〥	HANGZHOU NUMERAL FIVE                                           	Nl	None	None	5.0
# 〦	HANGZHOU NUMERAL SIX                                            	Nl	None	None	6.0
# 〧	HANGZHOU NUMERAL SEVEN                                          	Nl	None	None	7.0
# 〨	HANGZHOU NUMERAL EIGHT                                          	Nl	None	None	8.0
# 〩	HANGZHOU NUMERAL NINE                                           	Nl	None	None	9.0
# 〸	HANGZHOU NUMERAL TEN                                            	Nl	None	None	10.0
# 〹	HANGZHOU NUMERAL TWENTY                                         	Nl	None	None	20.0
# 〺	HANGZHOU NUMERAL THIRTY                                         	Nl	None	None	30.0
# ㆒	IDEOGRAPHIC ANNOTATION ONE MARK                                 	No	None	None	1.0
# ㆓	IDEOGRAPHIC ANNOTATION TWO MARK                                 	No	None	None	2.0
# ㆔	IDEOGRAPHIC ANNOTATION THREE MARK                               	No	None	None	3.0
# ㆕	IDEOGRAPHIC ANNOTATION FOUR MARK                                	No	None	None	4.0
# ㈠	PARENTHESIZED IDEOGRAPH ONE                                     	No	None	None	1.0
# ㈡	PARENTHESIZED IDEOGRAPH TWO                                     	No	None	None	2.0
# ㈢	PARENTHESIZED IDEOGRAPH THREE                                   	No	None	None	3.0
# ㈣	PARENTHESIZED IDEOGRAPH FOUR                                    	No	None	None	4.0
# ㈤	PARENTHESIZED IDEOGRAPH FIVE                                    	No	None	None	5.0
# ㈥	PARENTHESIZED IDEOGRAPH SIX                                     	No	None	None	6.0
# ㈦	PARENTHESIZED IDEOGRAPH SEVEN                                   	No	None	None	7.0
# ㈧	PARENTHESIZED IDEOGRAPH EIGHT                                   	No	None	None	8.0
# ㈨	PARENTHESIZED IDEOGRAPH NINE                                    	No	None	None	9.0
# ㈩	PARENTHESIZED IDEOGRAPH TEN                                     	No	None	None	10.0
# ㉈	CIRCLED NUMBER TEN ON BLACK SQUARE                              	No	None	None	10.0
# ...
# 𝟾	MATHEMATICAL MONOSPACE DIGIT EIGHT                              	Nd	8	8	8.0
# 𝟿	MATHEMATICAL MONOSPACE DIGIT NINE                               	Nd	9	9	9.0
# 𞅀	NYIAKENG PUACHUE HMONG DIGIT ZERO                               	Nd	0	0	0.0
# 𞅁	NYIAKENG PUACHUE HMONG DIGIT ONE                                	Nd	1	1	1.0
# 𞅂	NYIAKENG PUACHUE HMONG DIGIT TWO                                	Nd	2	2	2.0
# 𞅃	NYIAKENG PUACHUE HMONG DIGIT THREE                              	Nd	3	3	3.0
# 𞅄	NYIAKENG PUACHUE HMONG DIGIT FOUR                               	Nd	4	4	4.0
# 𞅅	NYIAKENG PUACHUE HMONG DIGIT FIVE                               	Nd	5	5	5.0
# 𞅆	NYIAKENG PUACHUE HMONG DIGIT SIX                                	Nd	6	6	6.0
# 𞅇	NYIAKENG PUACHUE HMONG DIGIT SEVEN                              	Nd	7	7	7.0
# 𞅈	NYIAKENG PUACHUE HMONG DIGIT EIGHT                              	Nd	8	8	8.0
# 𞅉	NYIAKENG PUACHUE HMONG DIGIT NINE                               	Nd	9	9	9.0
# 𞋰	WANCHO DIGIT ZERO                                               	Nd	0	0	0.0
# 𞋱	WANCHO DIGIT ONE                                                	Nd	1	1	1.0
# 𞋲	WANCHO DIGIT TWO                                                	Nd	2	2	2.0
# 𞋳	WANCHO DIGIT THREE                                              	Nd	3	3	3.0
# 𞋴	WANCHO DIGIT FOUR                                               	Nd	4	4	4.0
# 𞋵	WANCHO DIGIT FIVE                                               	Nd	5	5	5.0
# 𞋶	WANCHO DIGIT SIX                                                	Nd	6	6	6.0
# 𞋷	WANCHO DIGIT SEVEN                                              	Nd	7	7	7.0
# 𞋸	WANCHO DIGIT EIGHT                                              	Nd	8	8	8.0
# 𞋹	WANCHO DIGIT NINE                                               	Nd	9	9	9.0
# 𞣇	MENDE KIKAKUI DIGIT ONE                                         	No	None	None	1.0
# 𞣈	MENDE KIKAKUI DIGIT TWO                                         	No	None	None	2.0
# 𞣉	MENDE KIKAKUI DIGIT THREE                                       	No	None	None	3.0
# 𞣊	MENDE KIKAKUI DIGIT FOUR                                        	No	None	None	4.0
# 𞣋	MENDE KIKAKUI DIGIT FIVE                                        	No	None	None	5.0
# 𞣌	MENDE KIKAKUI DIGIT SIX                                         	No	None	None	6.0
# 𞣍	MENDE KIKAKUI DIGIT SEVEN                                       	No	None	None	7.0
# 𞣎	MENDE KIKAKUI DIGIT EIGHT                                       	No	None	None	8.0
# 𞣏	MENDE KIKAKUI DIGIT NINE                                        	No	None	None	9.0
# 𞥐	ADLAM DIGIT ZERO                                                	Nd	0	0	0.0
# 𞥑	ADLAM DIGIT ONE                                                 	Nd	1	1	1.0
# 𞥒	ADLAM DIGIT TWO                                                 	Nd	2	2	2.0
# 𞥓	ADLAM DIGIT THREE                                               	Nd	3	3	3.0
# 𞥔	ADLAM DIGIT FOUR                                                	Nd	4	4	4.0
# 𞥕	ADLAM DIGIT FIVE                                                	Nd	5	5	5.0
# 𞥖	ADLAM DIGIT SIX                                                 	Nd	6	6	6.0
# 𞥗	ADLAM DIGIT SEVEN                                               	Nd	7	7	7.0
# 𞥘	ADLAM DIGIT EIGHT                                               	Nd	8	8	8.0
# 𞥙	ADLAM DIGIT NINE                                                	Nd	9	9	9.0
# 𞱱	INDIC SIYAQ NUMBER ONE                                          	No	None	None	1.0
# 𞱲	INDIC SIYAQ NUMBER TWO                                          	No	None	None	2.0
# 𞱳	INDIC SIYAQ NUMBER THREE                                        	No	None	None	3.0
# 𞱴	INDIC SIYAQ NUMBER FOUR                                         	No	None	None	4.0
# 𞱵	INDIC SIYAQ NUMBER FIVE                                         	No	None	None	5.0
# 𞱶	INDIC SIYAQ NUMBER SIX                                          	No	None	None	6.0
# 𞱷	INDIC SIYAQ NUMBER SEVEN                                        	No	None	None	7.0
# 𞱸	INDIC SIYAQ NUMBER EIGHT                                        	No	None	None	8.0
# 𞱹	INDIC SIYAQ NUMBER NINE                                         	No	None	None	9.0
# 𞱺	INDIC SIYAQ NUMBER TEN                                          	No	None	None	10.0
# 𞱻	INDIC SIYAQ NUMBER TWENTY                                       	No	None	None	20.0
# 𞱼	INDIC SIYAQ NUMBER THIRTY                                       	No	None	None	30.0
# 𞱽	INDIC SIYAQ NUMBER FORTY                                        	No	None	None	40.0
# 𞱾	INDIC SIYAQ NUMBER FIFTY                                        	No	None	None	50.0
# 𞱿	INDIC SIYAQ NUMBER SIXTY                                        	No	None	None	60.0
# 𞲀	INDIC SIYAQ NUMBER SEVENTY                                      	No	None	None	70.0
# 𞲁	INDIC SIYAQ NUMBER EIGHTY                                       	No	None	None	80.0
# 𞲂	INDIC SIYAQ NUMBER NINETY                                       	No	None	None	90.0
# 𞲃	INDIC SIYAQ NUMBER ONE HUNDRED                                  	No	None	None	100.0
# 𞲄	INDIC SIYAQ NUMBER TWO HUNDRED                                  	No	None	None	200.0
# 𞲅	INDIC SIYAQ NUMBER THREE HUNDRED                                	No	None	None	300.0
# 𞲆	INDIC SIYAQ NUMBER FOUR HUNDRED                                 	No	None	None	400.0
# 𞲇	INDIC SIYAQ NUMBER FIVE HUNDRED                                 	No	None	None	500.0
# 𞲈	INDIC SIYAQ NUMBER SIX HUNDRED                                  	No	None	None	600.0
# 𞲉	INDIC SIYAQ NUMBER SEVEN HUNDRED                                	No	None	None	700.0
# 𞲊	INDIC SIYAQ NUMBER EIGHT HUNDRED                                	No	None	None	800.0
# 𞲋	INDIC SIYAQ NUMBER NINE HUNDRED                                 	No	None	None	900.0
# 𞲌	INDIC SIYAQ NUMBER ONE THOUSAND                                 	No	None	None	1000.0
# 𞲍	INDIC SIYAQ NUMBER TWO THOUSAND                                 	No	None	None	2000.0
# 𞲎	INDIC SIYAQ NUMBER THREE THOUSAND                               	No	None	None	3000.0
# 𞲏	INDIC SIYAQ NUMBER FOUR THOUSAND                                	No	None	None	4000.0
# 𞲐	INDIC SIYAQ NUMBER FIVE THOUSAND                                	No	None	None	5000.0
# 𞲑	INDIC SIYAQ NUMBER SIX THOUSAND                                 	No	None	None	6000.0
# 𞲒	INDIC SIYAQ NUMBER SEVEN THOUSAND                               	No	None	None	7000.0
# 𞲓	INDIC SIYAQ NUMBER EIGHT THOUSAND                               	No	None	None	8000.0
# 𞲔	INDIC SIYAQ NUMBER NINE THOUSAND                                	No	None	None	9000.0
# 𞲕	INDIC SIYAQ NUMBER TEN THOUSAND                                 	No	None	None	10000.0
# 𞲖	INDIC SIYAQ NUMBER TWENTY THOUSAND                              	No	None	None	20000.0
# 𞲗	INDIC SIYAQ NUMBER THIRTY THOUSAND                              	No	None	None	30000.0
# 𞲘	INDIC SIYAQ NUMBER FORTY THOUSAND                               	No	None	None	40000.0
# 𞲙	INDIC SIYAQ NUMBER FIFTY THOUSAND                               	No	None	None	50000.0
# 𞲚	INDIC SIYAQ NUMBER SIXTY THOUSAND                               	No	None	None	60000.0
# 𞲛	INDIC SIYAQ NUMBER SEVENTY THOUSAND                             	No	None	None	70000.0
# 𞲜	INDIC SIYAQ NUMBER EIGHTY THOUSAND                              	No	None	None	80000.0
# 𞲝	INDIC SIYAQ NUMBER NINETY THOUSAND                              	No	None	None	90000.0
# 𞲞	INDIC SIYAQ NUMBER LAKH                                         	No	None	None	100000.0
# 𞲟	INDIC SIYAQ NUMBER LAKHAN                                       	No	None	None	200000.0
# 𞲠	INDIC SIYAQ LAKH MARK                                           	No	None	None	100000.0
# 𞲡	INDIC SIYAQ NUMBER KAROR                                        	No	None	None	10000000.0
# 𞲢	INDIC SIYAQ NUMBER KARORAN                                      	No	None	None	20000000.0
# 𞲣	INDIC SIYAQ NUMBER PREFIXED ONE                                 	No	None	None	1.0
# 𞲤	INDIC SIYAQ NUMBER PREFIXED TWO                                 	No	None	None	2.0
# 𞲥	INDIC SIYAQ NUMBER PREFIXED THREE                               	No	None	None	3.0
# 𞲦	INDIC SIYAQ NUMBER PREFIXED FOUR                                	No	None	None	4.0
# 𞲧	INDIC SIYAQ NUMBER PREFIXED FIVE                                	No	None	None	5.0
# 𞲨	INDIC SIYAQ NUMBER PREFIXED SIX                                 	No	None	None	6.0
# 𞲩	INDIC SIYAQ NUMBER PREFIXED SEVEN                               	No	None	None	7.0
# 𞲪	INDIC SIYAQ NUMBER PREFIXED EIGHT                               	No	None	None	8.0
# 𞲫	INDIC SIYAQ NUMBER PREFIXED NINE                                	No	None	None	9.0
# 𞲭	INDIC SIYAQ FRACTION ONE QUARTER                                	No	None	None	0.25
# 𞲮	INDIC SIYAQ FRACTION ONE HALF                                   	No	None	None	0.5
# 𞲯	INDIC SIYAQ FRACTION THREE QUARTERS                             	No	None	None	0.75
# 𞲱	INDIC SIYAQ NUMBER ALTERNATE ONE                                	No	None	None	1.0
# 𞲲	INDIC SIYAQ NUMBER ALTERNATE TWO                                	No	None	None	2.0
# 𞲳	INDIC SIYAQ NUMBER ALTERNATE TEN THOUSAND                       	No	None	None	10000.0
# 𞲴	INDIC SIYAQ ALTERNATE LAKH MARK                                 	No	None	None	100000.0
# 𞴁	OTTOMAN SIYAQ NUMBER ONE                                        	No	None	None	1.0
# 𞴂	OTTOMAN SIYAQ NUMBER TWO                                        	No	None	None	2.0
# 𞴃	OTTOMAN SIYAQ NUMBER THREE                                      	No	None	None	3.0
# 𞴄	OTTOMAN SIYAQ NUMBER FOUR                                       	No	None	None	4.0
# 𞴅	OTTOMAN SIYAQ NUMBER FIVE                                       	No	None	None	5.0
# 𞴆	OTTOMAN SIYAQ NUMBER SIX                                        	No	None	None	6.0
# 𞴇	OTTOMAN SIYAQ NUMBER SEVEN                                      	No	None	None	7.0
# 𞴈	OTTOMAN SIYAQ NUMBER EIGHT                                      	No	None	None	8.0
# 𞴉	OTTOMAN SIYAQ NUMBER NINE                                       	No	None	None	9.0
# 𞴊	OTTOMAN SIYAQ NUMBER TEN                                        	No	None	None	10.0
# 𞴋	OTTOMAN SIYAQ NUMBER TWENTY                                     	No	None	None	20.0
# 𞴌	OTTOMAN SIYAQ NUMBER THIRTY                                     	No	None	None	30.0
# 𞴍	OTTOMAN SIYAQ NUMBER FORTY                                      	No	None	None	40.0
# 𞴎	OTTOMAN SIYAQ NUMBER FIFTY                                      	No	None	None	50.0
# 𞴏	OTTOMAN SIYAQ NUMBER SIXTY                                      	No	None	None	60.0
# 𞴐	OTTOMAN SIYAQ NUMBER SEVENTY                                    	No	None	None	70.0
# 𞴑	OTTOMAN SIYAQ NUMBER EIGHTY                                     	No	None	None	80.0
# 𞴒	OTTOMAN SIYAQ NUMBER NINETY                                     	No	None	None	90.0
# 𞴓	OTTOMAN SIYAQ NUMBER ONE HUNDRED                                	No	None	None	100.0
# 𞴔	OTTOMAN SIYAQ NUMBER TWO HUNDRED                                	No	None	None	200.0
# 𞴕	OTTOMAN SIYAQ NUMBER THREE HUNDRED                              	No	None	None	300.0
# 𞴖	OTTOMAN SIYAQ NUMBER FOUR HUNDRED                               	No	None	None	400.0
# 𞴗	OTTOMAN SIYAQ NUMBER FIVE HUNDRED                               	No	None	None	500.0
# 𞴘	OTTOMAN SIYAQ NUMBER SIX HUNDRED                                	No	None	None	600.0
# 𞴙	OTTOMAN SIYAQ NUMBER SEVEN HUNDRED                              	No	None	None	700.0
# 𞴚	OTTOMAN SIYAQ NUMBER EIGHT HUNDRED                              	No	None	None	800.0
# 𞴛	OTTOMAN SIYAQ NUMBER NINE HUNDRED                               	No	None	None	900.0
# 𞴜	OTTOMAN SIYAQ NUMBER ONE THOUSAND                               	No	None	None	1000.0
# 𞴝	OTTOMAN SIYAQ NUMBER TWO THOUSAND                               	No	None	None	2000.0
# 𞴞	OTTOMAN SIYAQ NUMBER THREE THOUSAND                             	No	None	None	3000.0
# 𞴟	OTTOMAN SIYAQ NUMBER FOUR THOUSAND                              	No	None	None	4000.0
# 𞴠	OTTOMAN SIYAQ NUMBER FIVE THOUSAND                              	No	None	None	5000.0
# 𞴡	OTTOMAN SIYAQ NUMBER SIX THOUSAND                               	No	None	None	6000.0
# 𞴢	OTTOMAN SIYAQ NUMBER SEVEN THOUSAND                             	No	None	None	7000.0
# 𞴣	OTTOMAN SIYAQ NUMBER EIGHT THOUSAND                             	No	None	None	8000.0
# 𞴤	OTTOMAN SIYAQ NUMBER NINE THOUSAND                              	No	None	None	9000.0
# 𞴥	OTTOMAN SIYAQ NUMBER TEN THOUSAND                               	No	None	None	10000.0
# 𞴦	OTTOMAN SIYAQ NUMBER TWENTY THOUSAND                            	No	None	None	20000.0
# 𞴧	OTTOMAN SIYAQ NUMBER THIRTY THOUSAND                            	No	None	None	30000.0
# 𞴨	OTTOMAN SIYAQ NUMBER FORTY THOUSAND                             	No	None	None	40000.0
# 𞴩	OTTOMAN SIYAQ NUMBER FIFTY THOUSAND                             	No	None	None	50000.0
# 𞴪	OTTOMAN SIYAQ NUMBER SIXTY THOUSAND                             	No	None	None	60000.0
# 𞴫	OTTOMAN SIYAQ NUMBER SEVENTY THOUSAND                           	No	None	None	70000.0
# 𞴬	OTTOMAN SIYAQ NUMBER EIGHTY THOUSAND                            	No	None	None	80000.0
# 𞴭	OTTOMAN SIYAQ NUMBER NINETY THOUSAND                            	No	None	None	90000.0
# 𞴯	OTTOMAN SIYAQ ALTERNATE NUMBER TWO                              	No	None	None	2.0
# 𞴰	OTTOMAN SIYAQ ALTERNATE NUMBER THREE                            	No	None	None	3.0
# 𞴱	OTTOMAN SIYAQ ALTERNATE NUMBER FOUR                             	No	None	None	4.0
# 𞴲	OTTOMAN SIYAQ ALTERNATE NUMBER FIVE                             	No	None	None	5.0
# 𞴳	OTTOMAN SIYAQ ALTERNATE NUMBER SIX                              	No	None	None	6.0
# 𞴴	OTTOMAN SIYAQ ALTERNATE NUMBER SEVEN                            	No	None	None	7.0
# 𞴵	OTTOMAN SIYAQ ALTERNATE NUMBER EIGHT                            	No	None	None	8.0
# 𞴶	OTTOMAN SIYAQ ALTERNATE NUMBER NINE                             	No	None	None	9.0
# 𞴷	OTTOMAN SIYAQ ALTERNATE NUMBER TEN                              	No	None	None	10.0
# 𞴸	OTTOMAN SIYAQ ALTERNATE NUMBER FOUR HUNDRED                     	No	None	None	400.0
# 𞴹	OTTOMAN SIYAQ ALTERNATE NUMBER SIX HUNDRED                      	No	None	None	600.0
# 𞴺	OTTOMAN SIYAQ ALTERNATE NUMBER TWO THOUSAND                     	No	None	None	2000.0
# 𞴻	OTTOMAN SIYAQ ALTERNATE NUMBER TEN THOUSAND                     	No	None	None	10000.0
# 𞴼	OTTOMAN SIYAQ FRACTION ONE HALF                                 	No	None	None	0.5
# 𞴽	OTTOMAN SIYAQ FRACTION ONE SIXTH                                	No	None	None	0.16666666666666666
# 🄀	DIGIT ZERO FULL STOP                                            	No	None	0	0.0
# 🄁	DIGIT ZERO COMMA                                                	No	None	0	0.0
# 🄂	DIGIT ONE COMMA                                                 	No	None	1	1.0
# 🄃	DIGIT TWO COMMA                                                 	No	None	2	2.0
# 🄄	DIGIT THREE COMMA                                               	No	None	3	3.0
# 🄅	DIGIT FOUR COMMA                                                	No	None	4	4.0
# 🄆	DIGIT FIVE COMMA                                                	No	None	5	5.0
# 🄇	DIGIT SIX COMMA                                                 	No	None	6	6.0
# 🄈	DIGIT SEVEN COMMA                                               	No	None	7	7.0
# 🄉	DIGIT EIGHT COMMA                                               	No	None	8	8.0
# 🄊	DIGIT NINE COMMA                                                	No	None	9	9.0
# 🄋	DINGBAT CIRCLED SANS-SERIF DIGIT ZERO                           	No	None	None	0.0
# 🄌	DINGBAT NEGATIVE CIRCLED SANS-SERIF DIGIT ZERO                  	No	None	None	0.0
# 🯰	SEGMENTED DIGIT ZERO                                            	Nd	0	0	0.0
# 🯱	SEGMENTED DIGIT ONE                                             	Nd	1	1	1.0
# 🯲	SEGMENTED DIGIT TWO                                             	Nd	2	2	2.0
# 🯳	SEGMENTED DIGIT THREE                                           	Nd	3	3	3.0
# 🯴	SEGMENTED DIGIT FOUR                                            	Nd	4	4	4.0
# 🯵	SEGMENTED DIGIT FIVE                                            	Nd	5	5	5.0
# 🯶	SEGMENTED DIGIT SIX                                             	Nd	6	6	6.0
# 🯷	SEGMENTED DIGIT SEVEN                                           	Nd	7	7	7.0
# 🯸	SEGMENTED DIGIT EIGHT                                           	Nd	8	8	8.0
# 🯹	SEGMENTED DIGIT NINE                                            	Nd	9	9	9.0

# %% [markdown]
# ## Equivalent identifiers
#
# Python supports Unicode identifiers (names for variables) by closely following
# the associated [Unicode guidelines](https://unicode.org/reports/tr31/).
#
# Here, we assign a value to a name spelled with full-width kana and note that
# Python treats the half-width kana form as the _same_ identifier.

# %%
パイソン = 42
print(ﾊﾟｲｿﾝ)
# Out:
# 42

# %% [markdown]
# ## Identifiers are considered equivalent under NFKC
#
# As described [in the Python documentation](https://docs.python.org/3/reference/lexical_analysis.html#identifiers),
# Python source code is transformed at parse time:
#
# > All identifiers are converted into the normal form NFKC while parsing; **comparison of identifiers is based on NFKC.**

# %%
# we can confirm that these are the same after applying NFKC
unicodedata.normalize("NFKC", "ﾊﾟｲｿﾝ") == unicodedata.normalize("NFKC", "パイソン")
# Out:
# True

# %% [markdown]
# ## We also explored this behavior with an identifier inspired by an earlier example

# %%
çava = 42   # 6 codepoints
print(çava) # 7 codepoints
# Out:
# 42

# %% [markdown]
# ## We aren't allowed to use _anything_ as an identifier
#
# Only some characters are allowed in identifiers, so we aren't allowed to use
# emoji as names, for instance.

# %%
🐍 = 42
# Out:
#   Input In [14]
#     🐍 = 42
#     ^
# SyntaxError: invalid character '🐍' (U+1F40D)
